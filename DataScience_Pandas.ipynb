# %% [markdown]
# <a href="https://colab.research.google.com/github/helenksouza/helenksouza/blob/main/DataScience_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2

# %%
pip install -U wget

# %% [markdown]
# # Pandas

# %% [markdown]
# * Pacote de análise de dados.
#
# * Sem limitação de  tamanho.
#
# * Excel máximo: 2GB 1milhão linha x 16 mil colunas

# %% [markdown]
# Series- array np -> DataFrame

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv') #/content/sample_data/california_housing_test.csv

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df['longitude']
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
type(df['longitude'])
# Out:
# pandas.core.series.Series

# %%
df['longitude'] = df['longitude'] * 2 #operação vetorizada

# %%
df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -244.10     37.37  ...         6.6085            344700.0
# 1    -236.60     34.26  ...         3.5990            176500.0
# 2    -235.62     33.78  ...         5.7934            270500.0
# 3    -236.72     33.82  ...         6.1359            330000.0
# 4    -239.34     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
df.loc[1, : ]
# Out:
# longitude               -236.600
# latitude                  34.260
# housing_median_age        43.000
# total_rooms             1510.000
# total_bedrooms           310.000
# population               809.000
# households               277.000
# median_income              3.599
# median_house_value    176500.000
# Name: 1, dtype: float64

# %%
type(df.loc[1, : ]) #1ª linha e tds colunas
# Out:
# pandas.core.series.Series

# %%
df.loc[1, 'latitude']
# Out:
# 34.26

# %%
df.loc[df['housing_median_age'] > 27, :]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 1       -236.60     34.26  ...         3.5990            176500.0
# 3       -236.72     33.82  ...         6.1359            330000.0
# 5       -239.12     36.51  ...         1.6635             67000.0
# 6       -242.86     38.63  ...         1.6641             67000.0
# 9       -236.04     34.08  ...         2.3333            164200.0
# ...         ...       ...  ...            ...                 ...
# 2992    -244.66     37.39  ...         6.2263            500001.0
# 2993    -235.82     33.60  ...         5.1048            500001.0
# 2994    -235.86     33.86  ...         5.5867            182500.0
# 2998    -234.24     34.10  ...         3.2708            162500.0
# 2999    -239.26     34.42  ...         8.5608            500001.0
#
# [1610 rows x 9 columns]

# %% [markdown]
# ## Dados Abertos

# %%
import os #comando abrir/fechar ir para pasta
import wget #!wgethttps://www.camara.leg.br/cotas/Ano-2021.csv.zip
import glob

# %% [markdown]
# https://dadosabertos.camara.leg.br/

# %% [markdown]
# !wgethttps://www.camara.leg.br/cotas/Ano-2021.csv.zip

# %%
# !wget https://www.camara.leg.br/cotas/Ano-2021.csv.zip
# Out:
# --2021-11-16 01:37:24--  https://www.camara.leg.br/cotas/Ano-2021.csv.zip
# Resolving www.camara.leg.br (www.camara.leg.br)... 200.219.133.54, 200.219.133.58, 200.219.133.84
# Connecting to www.camara.leg.br (www.camara.leg.br)|200.219.133.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4934455 (4.7M) [application/zip]
# Saving to: ‘Ano-2021.csv.zip.1’
#
# Ano-2021.csv.zip.1  100%[===================>]   4.71M  1.93MB/s    in 2.4s
#
# 2021-11-16 01:37:28 (1.93 MB/s) - ‘Ano-2021.csv.zip.1’ saved [4934455/4934455]

# %%
  anos = range(2008, 2022) #final excluso

  for ano in anos:
    url = f'https://www.camara.leg.br/cotas/Ano-{ano}.csv.zip' #string formatado

    print(url)
# Out:
# https://www.camara.leg.br/cotas/Ano-2008.csv.zip
# https://www.camara.leg.br/cotas/Ano-2009.csv.zip
# https://www.camara.leg.br/cotas/Ano-2010.csv.zip
# https://www.camara.leg.br/cotas/Ano-2011.csv.zip
# https://www.camara.leg.br/cotas/Ano-2012.csv.zip
# https://www.camara.leg.br/cotas/Ano-2013.csv.zip
# https://www.camara.leg.br/cotas/Ano-2014.csv.zip
# https://www.camara.leg.br/cotas/Ano-2015.csv.zip
# https://www.camara.leg.br/cotas/Ano-2016.csv.zip
# https://www.camara.leg.br/cotas/Ano-2017.csv.zip
# https://www.camara.leg.br/cotas/Ano-2018.csv.zip
# https://www.camara.leg.br/cotas/Ano-2019.csv.zip
# https://www.camara.leg.br/cotas/Ano-2020.csv.zip
# https://www.camara.leg.br/cotas/Ano-2021.csv.zip

# %%
if len(os.listdir('./data/')) == 0: #ñ baixando varias vezes

  anos = range(2008, 2022) #final excluso

  for ano in anos:
    url = f'https://www.camara.leg.br/cotas/Ano-{ano}.csv.zip' #string formatado
    wget.download(url, out='./data/') #baixando na pasta data

# %%
pwd()
# Out:
# '/content'

# %%
os.listdir() #vendo arquivos
# Out:
# ['.config',
#  'movie.mp4',
#  'Ano-2021.csv.zip.1',
#  'data',
#  'Ano-2021.csv.zip',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
len(os.listdir())
# Out:
# 7

# %% [markdown]
# LENDO:

# %%
files = glob.glob('./data/*.csv.zip') #arquivos que terminam com csv.zip

# %%
files
# Out:
# ['./data/Ano-2013.csv.zip',
#  './data/Ano-2009.csv.zip',
#  './data/Ano-2017.csv.zip',
#  './data/Ano-2020.csv.zip',
#  './data/Ano-2018.csv.zip',
#  './data/Ano-2019.csv.zip',
#  './data/Ano-2012.csv.zip',
#  './data/Ano-2014.csv.zip',
#  './data/Ano-2008.csv.zip',
#  './data/Ano-2015.csv.zip',
#  './data/Ano-2021.csv.zip',
#  './data/Ano-2011.csv.zip',
#  './data/Ano-2010.csv.zip',
#  './data/Ano-2016.csv.zip']

# %%
dfs
# Out:
# [       txNomeParlamentar           cpf  ...  ideDocumento  urlDocumento
#  0       LIDERANÇA DO PDT           NaN  ...       5159141           NaN
#  1       LIDERANÇA DO PDT           NaN  ...       5165750           NaN
#  2       LIDERANÇA DO PDT           NaN  ...       5177451           NaN
#  3       LIDERANÇA DO PDT           NaN  ...       5227489           NaN
#  4       LIDERANÇA DO PDT           NaN  ...       5244951           NaN
#  ...                  ...           ...  ...           ...           ...
#  391523      HELCIO SILVA  4.846362e+09  ...       5316393           NaN
#  391524      HELCIO SILVA  4.846362e+09  ...       5316410           NaN
#  391525      HELCIO SILVA  4.846362e+09  ...       5316414           NaN
#  391526      HELCIO SILVA  4.846362e+09  ...        751090           NaN
#  391527      HELCIO SILVA  4.846362e+09  ...        792236           NaN
#
#  [391528 rows x 31 columns],
# ...

# %%
dfs[0]
# Out:
#        txNomeParlamentar           cpf  ...  ideDocumento  urlDocumento
# 0       LIDERANÇA DO PDT           NaN  ...       5159141           NaN
# 1       LIDERANÇA DO PDT           NaN  ...       5165750           NaN
# 2       LIDERANÇA DO PDT           NaN  ...       5177451           NaN
# 3       LIDERANÇA DO PDT           NaN  ...       5227489           NaN
# 4       LIDERANÇA DO PDT           NaN  ...       5244951           NaN
# ...                  ...           ...  ...           ...           ...
# 391523      HELCIO SILVA  4.846362e+09  ...       5316393           NaN
# 391524      HELCIO SILVA  4.846362e+09  ...       5316410           NaN
# 391525      HELCIO SILVA  4.846362e+09  ...       5316414           NaN
# 391526      HELCIO SILVA  4.846362e+09  ...        751090           NaN
# 391527      HELCIO SILVA  4.846362e+09  ...        792236           NaN
#
# [391528 rows x 31 columns]

# %%
files = glob.glob('./data/*.csv.zip') #arquivos que terminam com csv.zip
dfs = [pd.read_csv(item, compression='zip', sep=';') for item in files]

deps = pd.concat(dfs, ignore_index=True) #conactendando ao longo das colunas #axis=1 um do lado do outro

# %%
deps = pd.concat(dfs, ignore_index=True)

# %%
deps.shape
# Out:
# (4157783, 31)

# %%
deps.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4157783 entries, 0 to 4157782
# Data columns (total 31 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   txNomeParlamentar          object
#  1   cpf                        float64
#  2   ideCadastro                float64
#  3   nuCarteiraParlamentar      float64
#  4   nuLegislatura              int64
#  5   sgUF                       object
#  6   sgPartido                  object
#  7   codLegislatura             int64
#  8   numSubCota                 int64
#  9   txtDescricao               object
#  10  numEspecificacaoSubCota    int64
#  11  txtDescricaoEspecificacao  object
#  12  txtFornecedor              object
#  13  txtCNPJCPF                 object
#  14  txtNumero                  object
#  15  indTipoDocumento           int64
#  16  datEmissao                 object
#  17  vlrDocumento               float64
#  18  vlrGlosa                   float64
# ...

# %%
deps.head(6)
# Out:
#   txNomeParlamentar  cpf  ideCadastro  ...  nuDeputadoId  ideDocumento urlDocumento
# 0  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5159141          NaN
# 1  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5165750          NaN
# 2  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5177451          NaN
# 3  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5227489          NaN
# 4  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5244951          NaN
# 5  LIDERANÇA DO PDT  NaN          NaN  ...          2715       5273539          NaN
#
# [6 rows x 31 columns]

# %%
deps.tail(6) #últimos linhas
# Out:
#         txNomeParlamentar           cpf  ...  ideDocumento  urlDocumento
# 4157777     POLLYANA GAMA  1.221001e+10  ...       1382917           NaN
# 4157778     POLLYANA GAMA  1.221001e+10  ...       1384860           NaN
# 4157779     POLLYANA GAMA  1.221001e+10  ...       1384969           NaN
# 4157780     POLLYANA GAMA  1.221001e+10  ...       1385379           NaN
# 4157781     POLLYANA GAMA  1.221001e+10  ...       1388973           NaN
# 4157782     POLLYANA GAMA  1.221001e+10  ...       1390266           NaN
#
# [6 rows x 31 columns]

# %%
deps.sample(10)
# Out:
#             txNomeParlamentar  ...                                       urlDocumento
# 2728833         SÁGUAS MORAES  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 3599491       SEVERIANO ALVES  ...                                                NaN
# 1069124         Túlio Gadêlha  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 4152775          WADIH DAMOUS  ...                                                NaN
# 1612614           Jorge Solla  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2423963         EDSON PIMENTA  ...                                                NaN
# 2795934  Evair Vieira de Melo  ...                                                NaN
# 1672802        Sargento Fahur  ...  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2862702          ANA PERUGINI  ...  https://www.camara.leg.br/cota-parlamentar/doc...
# 1086290        Domingos Sávio  ...  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [10 rows x 31 columns]

# %%
deps.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'vlrRestituicao', 'nuDeputadoId', 'ideDocumento',
#        'urlDocumento'],
#       dtype='object')

# %%
deps.index
# Out:
# RangeIndex(start=0, stop=4157783, step=1)

# %% [markdown]
# ## As perguntas
#
#
# - Os gastos por ano
# - Os gastos por mes
# - Qual deputado gastou mais em cada legislatura
# - Quais itens são os gastos principais dos deputados
# - Quem é o deputado mais novo na hora de entrar
# - Quem é o deputado mais velho na hora de entrar
# - Qual deputado viajou mais do que todo mundo
# -

# %%
deps['datEmissao']
# Out:
# 0          2013-05-28T00:00:00
# 1          2013-06-27T00:00:00
# 2          2013-07-29T00:00:00
# 3          2013-08-28T00:00:00
# 4          2013-09-26T00:00:00
#                   ...
# 4157778    2016-12-12T00:00:00
# 4157779    2016-12-12T00:00:00
# 4157780    2016-12-15T00:00:00
# 4157781    2016-12-19T00:00:00
# 4157782    2016-12-20T00:00:00
# Name: datEmissao, Length: 4157783, dtype: object

# %%
deps['datEmissao'] = pd.to_datetime(deps['datEmissao']) #convertendo para temo

# %%
deps['datEmissao']
# Out:
# 0         2013-05-28
# 1         2013-06-27
# 2         2013-07-29
# 3         2013-08-28
# 4         2013-09-26
#              ...
# 4157778   2016-12-12
# 4157779   2016-12-12
# 4157780   2016-12-15
# 4157781   2016-12-19
# 4157782   2016-12-20
# Name: datEmissao, Length: 4157783, dtype: datetime64[ns]

# %%
deps[deps['datEmissao'].isnull()]
# Out:
#         txNomeParlamentar           cpf  ...  ideDocumento  urlDocumento
# 523          JAIRO ATAÍDE  3.428312e+09  ...             0           NaN
# 524          JAIRO ATAÍDE  3.428312e+09  ...             0           NaN
# 525          JAIRO ATAÍDE  3.428312e+09  ...             0           NaN
# 526          JAIRO ATAÍDE  3.428312e+09  ...             0           NaN
# 527          JAIRO ATAÍDE  3.428312e+09  ...             0           NaN
# ...                   ...           ...  ...           ...           ...
# 4157745     POLLYANA GAMA  1.221001e+10  ...             0           NaN
# 4157746     POLLYANA GAMA  1.221001e+10  ...             0           NaN
# 4157747     POLLYANA GAMA  1.221001e+10  ...             0           NaN
# 4157748     POLLYANA GAMA  1.221001e+10  ...             0           NaN
# 4157749     POLLYANA GAMA  1.221001e+10  ...             0           NaN
#
# [201055 rows x 31 columns]

# %%
deps['datEmissao'].min()
# Out:
# Timestamp('1959-11-03 00:00:00')

# %%
deps['datEmissao'].max()
# Out:
# Timestamp('2021-11-12 16:44:11')

# %%
deps[ deps['datEmissao'].dt.year < 2008]['datEmissao']
# Out:
# 403666    1959-11-03
# 426292    2002-09-09
# 472887    2000-09-29
# 499149    2000-09-29
# 504559    2006-06-12
#              ...
# 3689686   2004-12-14
# 3702876   2007-07-14
# 3721623   2001-07-27
# 3733844   2005-02-05
# 3760548   2001-03-15
# Name: datEmissao, Length: 63, dtype: datetime64[ns]

# %%
deps[['numAno', 'numMes']]
# Out:
#          numAno  numMes
# 0          2013       6
# 1          2013       7
# 2          2013       8
# 3          2013       9
# 4          2013       9
# ...         ...     ...
# 4157778    2016      12
# 4157779    2016      12
# 4157780    2016      12
# 4157781    2016      12
# 4157782    2016      12
#
# [4157783 rows x 2 columns]

# %%
deps[deps['numAno'].isnull()]
# Out:
# Empty DataFrame
# Columns: [txNomeParlamentar, cpf, ideCadastro, nuCarteiraParlamentar, nuLegislatura, sgUF, sgPartido, codLegislatura, numSubCota, txtDescricao, numEspecificacaoSubCota, txtDescricaoEspecificacao, txtFornecedor, txtCNPJCPF, txtNumero, indTipoDocumento, datEmissao, vlrDocumento, vlrGlosa, vlrLiquido, numMes, numAno, numParcela, txtPassageiro, txtTrecho, numLote, numRessarcimento, vlrRestituicao, nuDeputadoId, ideDocumento, urlDocumento]
# Index: []

# %%
deps[deps['numMes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [txNomeParlamentar, cpf, ideCadastro, nuCarteiraParlamentar, nuLegislatura, sgUF, sgPartido, codLegislatura, numSubCota, txtDescricao, numEspecificacaoSubCota, txtDescricaoEspecificacao, txtFornecedor, txtCNPJCPF, txtNumero, indTipoDocumento, datEmissao, vlrDocumento, vlrGlosa, vlrLiquido, numMes, numAno, numParcela, txtPassageiro, txtTrecho, numLote, numRessarcimento, vlrRestituicao, nuDeputadoId, ideDocumento, urlDocumento]
# Index: []

# %%
deps['numMes']
# Out:
# 0           6
# 1           7
# 2           8
# 3           9
# 4           9
#            ..
# 4157778    12
# 4157779    12
# 4157780    12
# 4157781    12
# 4157782    12
# Name: numMes, Length: 4157783, dtype: int64

# %%
deps.loc[deps['datEmissao'].dt.year < 2008, 'numAno']
# Out:
# 403666     2009
# 426292     2009
# 472887     2009
# 499149     2009
# 504559     2009
#            ...
# 3689686    2010
# 3702876    2010
# 3721623    2010
# 3733844    2010
# 3760548    2010
# Name: numAno, Length: 63, dtype: int64

# %%
deps.loc[deps['datEmissao'].dt.year < 2008, 'numAno'].astype(str) + '/' + \
deps.loc[deps['datEmissao'].dt.year < 2008, 'numMes'].astype(str)
# Out:
# 403666     2009/11
# 426292      2009/9
# 472887      2009/9
# 499149      2009/9
# 504559      2009/6
#             ...
# 3689686    2010/11
# 3702876     2010/7
# 3721623     2010/7
# 3733844     2010/2
# 3760548     2010/3
# Length: 63, dtype: object

# %% [markdown]
# \: prox linha

# %%
pd.to_datetime(deps.loc[deps['datEmissao'].dt.year < 2008, 'numAno'].astype(str) + '/' + \
deps.loc[deps['datEmissao'].dt.year < 2008, 'numMes'].astype(str), 
format = '%Y/%m')
# Out:
# 403666    2009-11-01
# 426292    2009-09-01
# 472887    2009-09-01
# 499149    2009-09-01
# 504559    2009-06-01
#              ...
# 3689686   2010-11-01
# 3702876   2010-07-01
# 3721623   2010-07-01
# 3733844   2010-02-01
# 3760548   2010-03-01
# Length: 63, dtype: datetime64[ns]

# %%
deps.loc[deps['datEmissao'].dt.year < 2008, 'datEmissao'] = pd.to_datetime(deps.loc[deps['datEmissao'].dt.year < 2008, 'numAno'].astype(str) + '/' + \
deps.loc[deps['datEmissao'].dt.year < 2008, 'numMes'].astype(str), 
format = '%Y/%m')

# %%
deps['datEmissao'].min()
# Out:
# Timestamp('2008-01-01 00:00:00')
